# %%
data = open('../data/PGT-J-DATA.txt', 'r', encoding='utf8').read()

# %%
data = data.split()

# %%
len(data)
# Out:
# 274213

# %%
chunk = 256

for i in range(0,len(data),chunk):
    print(len(data[i:i+chunk]))
# Out:
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# ...
